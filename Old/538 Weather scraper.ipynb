# %%
# coding: utf-8
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
from urllib.request import urlopen
from urllib.request import Request
import os
headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}

def scrape_station(station):
    '''
    This function scrapes the weather data web pages from wunderground.com
    for the station you provide it.
    You can look up your city's weather station by performing a search for
    it on wunderground.com then clicking on the "History" section.
    The 4-letter name of the station will appear on that page.
    '''

    # Scrape between July 1, 2014 and July 1, 2015
    # You can change the dates here if you prefer to scrape a different range
    current_date = datetime(year=2014, month=7, day=1)
    end_date = datetime(year=2015, month=7, day=1)

    # Make sure a directory exists for the station web pages
    #os.mkdir(station)

    # Use .format(station, YYYY, M, D)
    lookup_URL = 'http://www.wunderground.com/history/airport/{}/{}/{}/{}/DailyHistory.html'
    
    
    while current_date != end_date:

        if current_date.day == 1:
            print(current_date)

        formatted_lookup_URL = lookup_URL.format(station,
                                                 current_date.year,
                                                 current_date.month,
                                                 current_date.day)
        
        req = Request(formatted_lookup_URL,data=None, headers=headers)
        html = urlopen(req).read().decode('utf-8')

        out_file_name = '{}/{}-{}-{}.html'.format(station, current_date.year,
                                                  current_date.month,
                                                  current_date.day)
        try:
            with open(out_file_name, 'w') as out_file:
                out_file.write(html)
        except:
            print('error can not save file')
            return html
        

        current_date += timedelta(days=1)


# Scrape the stations used in this article
#for station in ['KCLT', 'KCQT', 'KHOU', 'KIND', 'KJAX',
#   'KMDW', 'KNYC', 'KPHL', 'KPHX', 'KSEA']:
#scrape_station(station)

# %%
 formatted_lookup_URL = 'http://www.wunderground.com/history/airport/{KSMF}/{2019}/{8}/{1}/DailyHistory.html'

html = scrape_station('KSMF')
# Out:
# 2014-07-01 00:00:00
# error can not save file

# %%
import requests
from bs4 import BeautifulSoup

result = requests.get("https://www.whitehouse.gov/briefings-statements/")
#file_name = "https://www.wunderground.com/history/daily/us/ca/davis/KSMF/date/2019-8-14?cm_ven=localwx_history"
file_name = 'https://www.wunderground.com/history/daily/us/ca/davis/KSMF/date/2019-8-14?cm_ven=localwx_history'
result = requests.get(file_name)

src = result.content
#soup = BeautifulSoup(src, 'lxml')
soup = BeautifulSoup(src, 'html.parser')

# %%
 #weather_data = soup.find(id='historyTable').find_all('span', class_='wx-value')
#eather_data_units = soup.find(id='historyTable').find_all('td')
#result = requests.get("https://www.whitehouse.gov/briefings-statements/")
result = requests.get("https://www.wunderground.com/history/airport/College%20Park/2014/7/1/DailyHistory.html?hdf=1")

src = result.content
soup = BeautifulSoup(src, 'html.parser')
a =soup.find_all("span","wx-data")
count = 0
for tag_item in soup.contents:
    #city_tag = tag_item.find('a')
    #soup.find("span", "hickory")
# <b class="hickory">Hickory</b>
    print(tag_item)
    count +=1
    print(count)
print(count)
# Out:
# 1
# html
# 2
#
#
# 3
# [if IE 9]><html class="no-js ie9"> <![endif]
# 4
#
#
# 5
# [if gt IE 9]><!
# 6
#
# 7
# <html class="no-js "> <!--<![endif]-->
# <head>
# <title>Weather History for College Park, Maryland | Weather Underground</title>
# <link href="//icons.wxug.com/" rel="dns-prefetch"/>
# <link href="//api-ak.wunderground.com/" rel="dns-prefetch"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="320" name="MobileOptimized"/>
# <meta content="width=device-width, initial-scale=1, minimal-ui" name="viewport"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="Weather History for College Park, MD - Get Weather History data by the day, week, month, or year with details like temperature, humidity, wind, etc. on Weather Underground." name="description">
# ...

# %%
weather_data = soup.find(id='historyTable').find_all('span', class_='wx-value')
weather_data
# Out:
# [<span class="wx-value">82</span>,
#  <span class="wx-value">93</span>,
#  <span class="wx-value">87</span>,
#  <span class="wx-value">101</span>,
#  <span class="wx-value">71</span>,
#  <span class="wx-value">66</span>,
#  <span class="wx-value">50</span>,
#  <span class="wx-value">69</span>,
#  <span class="wx-value">0.00</span>,
#  <span class="wx-value">29.89</span>,
#  <span class="wx-value">3</span>,
#  <span class="wx-value">10</span>,
#  <span class="wx-value">17</span>,
#  <span class="wx-value">10</span>]

# %%
from datetime import datetime, timedelta
from urllib.request import urlopen
import os
station = 'KSMF'
current_date = datetime(year=2014, month=7, day=1)
end_date = datetime(year=2015, month=7, day=1)
out_file_name = '{}/{}-{}-{}.html'.format(station, current_date.year,
                                                  current_date.month,
                                                  current_date.day)

formatted_lookup_URL = lookup_URL.format(station,
                                                 current_date.year,
                                                 current_date.month,
                                                 current_date.day)

# %%
headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'}

# %%
headers
# Out:
# {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'}
