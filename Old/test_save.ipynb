# %%
# %matplotlib inline

import pandas as pd
import geopandas

import os

pd.options.display.max_rows = 10

# %%
cities = geopandas.read_file("zip://.//ca-places-boundaries.zip")
counties = geopandas.read_file("zip://.//ca-county-boundaries.zip")
state = geopandas.read_file("zip://.//ca-state-boundary.zip")

# %%
ax = cities.plot()
state.plot(ax=ax,color = 'red',alpha = .1)
counties.plot(ax = ax,edgecolor='k', facecolor='none')

# %%
counties.plot(edgecolor='k', facecolor='none')

# %%
os.chdir('C://Henry//Hack4California//data_ca_gov//')

# %%
davis = california[california['NAME']=='Davis']

davis
#belgium = countries.loc[countries['name'] == 'Belgium', 'geometry'].squeeze()
# Out:
#     STATEFP PLACEFP   PLACENS    GEOID   NAME    NAMELSAD LSAD CLASSFP  \
# 411      06   18100  02410296  0618100  Davis  Davis city   25      C1
#
#     PCICBSA PCINECTA  MTFCC FUNCSTAT     ALAND  AWATER     INTPTLAT  \
# 411       N        N  G4110        A  25607394   90331  +38.5561470
#
#          INTPTLON                                           geometry
# 411  -121.7377925  POLYGON ((-13558051.98530234 4656997.498821902...

# %%
california[california['CLASSFP']=='U2']
# Out:
#      STATEFP PLACEFP   PLACENS    GEOID                       NAME  \
# 489       06   00535  02583084  0600535                    Airport
# 513       06   02382  02407751  0602382  Aptos Hills-Larkin Valley
# 515       06   02553  02407756  0602553               Arden-Arcade
# 551       06   06150  02407832  0606150          Bertsch-Oceanview
# 563       06   06982  02407857  0606982    Black Point-Green Point
# ...      ...     ...       ...      ...                        ...
# 1485      06   84385  02409573  0684385        Westhaven-Moonstone
# 1495      06   84921  02409570  0684921   West Whittier-Los Nietos
# 1498      06   85208  02583184  0685208                 Whitewater
# 1500      06   85551  02409595  0685551                  Wilkerson
# 1520      06   86912  02409638  0686912            Yosemite Valley
#
#                            NAMELSAD LSAD CLASSFP PCICBSA PCINECTA  MTFCC  \
# 489                     Airport CDP   57      U2       N        N  G4210
# ...

# %%
pwd
# Out:
# 'C:\\Henry\\Hack4California\\data_ca_gov'
